# %%
from __future__ import print_function

import warnings
warnings.filterwarnings('ignore')

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import get_data, utils

# %%
# Set up experiment parameters
params = utils.Params("model_configurations/experiment_params.json")
X, y, cols = get_data.get_and_preprocess_cc(params)
#X = X.values

# %%
import pandas as pd

# %%
df = pd.DataFrame(X)

# %%
df.head()
# Out:
#    population numeric  householdsize numeric  racepctblack numeric  \
# 0               11980                   3.10                  1.37
# 1               23123                   2.82                  0.80
# 2               29344                   2.43                  0.74
# 3               16656                   2.40                  1.70
# 5              140494                   2.45                  2.51
#
#    racePctWhite numeric  racePctAsian numeric  racePctHisp numeric  \
# 0                 91.78                  6.50                 1.88
# 1                 95.57                  3.44                 0.85
# 2                 94.33                  3.43                 2.35
# 3                 97.35                  0.50                 0.70
# 5                 95.65                  0.90                 0.95
#
#    agePct12t21 numeric  agePct12t29 numeric  agePct16t24 numeric  \
# 0                12.47                21.44                10.93
# 1                11.01                21.30                10.48
# 2                11.36                25.88                11.01
# 3                12.55                25.20                12.19
# 5                18.09                32.89                20.04
#
#    agePct65up numeric  numbUrban numeric  pctUrban numeric  medIncome numeric  \
# 0               11.33              11980             100.0              75122
# 1               17.18              23123             100.0              47917
# 2               10.28              29344             100.0              35669
# 3               17.57                  0               0.0              20580
# 5               13.26             140494             100.0              21577
#
#    pctWWage numeric  ...  MedOwnCostPctInc numeric  \
# 0             89.24  ...                      1001
# 1             78.99  ...                       627
# 2             82.00  ...                       484
# 3             68.15  ...                       333
# 5             75.78  ...                       340
#
#    MedOwnCostPctIncNoMtg numeric  NumInShelters numeric  NumStreet numeric  \
# 0                           23.8                   21.1               14.0
# 1                           27.6                   20.7               12.5
# 2                           24.1                   21.7               11.6
# 3                           28.7                   20.6               14.5
# 5                           26.4                   17.3               11.7
#
#    PctForeignBorn numeric  PctBornSameState numeric  PctSameHouse85 numeric  \
# 0                      11                         0                   10.66
# 1                       0                         0                    8.30
# 2                      16                         0                    5.00
# 3                       0                         0                    2.04
# 5                     327                         4                    1.49
#
#    PctSameCity85 numeric  PctSameState85 numeric  LemasSwornFT numeric  \
# 0                  53.72                   65.29                 78.09
# 1                  77.17                   71.27                 90.22
# 2                  44.77                   36.60                 61.26
# 3                  88.71                   56.70                 90.17
# 5                  64.35                   42.29                 70.61
#
#    LemasSwFTPerPop numeric  PctUsePubTrans numeric  PolicCars numeric  \
# 0                    89.14                     6.5             1845.9
# 1                    96.12                    10.6             2186.7
# 2                    82.85                    10.6             2780.9
# 3                    96.24                     5.2             3217.7
# 5                    85.66                    70.4             1995.7
#
#    PolicOperBudg numeric
# 0                   9.63
# 1                   3.84
# 2                   4.37
# 3                   3.31
# 5                   0.97
#
# [5 rows x 100 columns]

# %%
df.describe()
# Out:
#        population numeric  householdsize numeric  racepctblack numeric  \
# count        1.994000e+03            1994.000000           1994.000000
# mean         5.225143e+04               2.706810              9.509694
# std          2.021475e+05               0.343156             14.101979
# min          1.000500e+04               1.600000              0.000000
# 25%          1.435925e+04               2.490000              0.940000
# 50%          2.268100e+04               2.650000              3.150000
# 75%          4.315375e+04               2.850000             11.965000
# max          7.322564e+06               5.280000             96.670000
#
#        racePctWhite numeric  racePctAsian numeric  racePctHisp numeric  \
# count           1994.000000           1994.000000          1994.000000
# mean              83.489218              2.750787             8.481610
# std               16.393607              4.648200            15.208788
# min                2.680000              0.030000             0.120000
# 25%               75.882500              0.612500             0.920000
# 50%               89.605000              1.240000             2.340000
# 75%               95.987500              2.737500             8.610000
# max               99.630000             57.460000            95.290000
#
#        agePct12t21 numeric  agePct12t29 numeric  agePct16t24 numeric  \
# count          1994.000000          1994.000000          1994.000000
# mean             14.431214            27.617357            13.985421
# std               4.478570             6.148044             5.896879
# min               4.580000             9.380000             4.640000
# 25%              12.230000            24.380000            11.340000
# 50%              13.620000            26.765000            12.540000
# 75%              15.387500            29.180000            14.357500
# max              54.400000            70.510000            63.620000
#
#        agePct65up numeric  numbUrban numeric  pctUrban numeric  \
# count         1994.000000       1.994000e+03       1994.000000
# mean            12.004599       4.667176e+04         69.621545
# std              4.803906       2.031508e+05         44.478865
# min              1.660000       0.000000e+00          0.000000
# 25%              8.922500       0.000000e+00          0.000000
# 50%             11.855000       1.734850e+04        100.000000
# 75%             14.547500       4.193150e+04        100.000000
# max             52.770000       7.322564e+06        100.000000
#
#        medIncome numeric  pctWWage numeric  ...  MedOwnCostPctInc numeric  \
# count        1994.000000       1994.000000  ...               1994.000000
# mean        33699.327482         78.079960  ...                502.730191
# std         13391.741380          7.844073  ...                172.522021
# min         11576.000000         31.680000  ...                192.000000
# 25%         23597.000000         73.225000  ...                363.000000
# 50%         30896.000000         78.380000  ...                467.000000
# 75%         41214.750000         83.705000  ...                621.000000
# max        123625.000000         96.620000  ...               1001.000000
#
#        MedOwnCostPctIncNoMtg numeric  NumInShelters numeric  \
# count                    1994.000000            1994.000000
# mean                       26.328034              21.209579
# std                         2.924401               2.968310
# min                        14.900000              14.100000
# 25%                        24.300000              19.100000
# 50%                        26.200000              21.200000
# 75%                        28.100000              23.300000
# max                        35.100000              32.700000
#
#        NumStreet numeric  PctForeignBorn numeric  PctBornSameState numeric  \
# count        1994.000000             1994.000000               1994.000000
# mean           13.025125               67.714644                 18.712136
# std             1.451879              581.134713                256.203872
# min            10.100000                0.000000                  0.000000
# 25%            11.900000                0.000000                  0.000000
# 50%            12.800000                0.000000                  0.000000
# 75%            13.800000               24.000000                  1.000000
# max            23.400000            23383.000000              10447.000000
#
#        PctSameHouse85 numeric  PctSameCity85 numeric  PctSameState85 numeric  \
# count             1994.000000            1994.000000             1994.000000
# mean                 7.605807              60.499870               51.323862
# std                  8.698456              17.059482               10.659650
# min                  0.180000               6.750000               11.830000
# 25%                  2.080000              48.865000               44.677500
# 50%                  4.490000              62.520000               51.870000
# 75%                  9.585000              74.375000               58.505000
# max                 60.400000              93.140000               78.560000
#
#        LemasSwornFT numeric  LemasSwFTPerPop numeric  PctUsePubTrans numeric  \
# count           1994.000000              1994.000000             1994.000000
# mean              77.114127                87.732728               27.962889
# std               10.791485                 7.448660              114.827752
# min               27.950000                32.830000                0.900000
# 25%               71.922500                84.732500                7.400000
# 50%               79.315000                89.635000               13.700000
# 75%               84.700000                92.730000               25.775000
# max               96.590000                99.900000             3569.800000
#
#        PolicCars numeric  PolicOperBudg numeric
# count        1994.000000            1994.000000
# mean         2789.862487               3.062944
# std          2920.185784               4.963083
# min            10.000000               0.000000
# 25%          1170.825000               0.350000
# 50%          1996.100000               1.220000
# 75%          3270.400000               3.377500
# max         44229.900000              54.330000
#
# [8 rows x 100 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
df_scaled = pd.DataFrame(X)
df_scaled.columns = df.columns

# %%
df_scaled.head()
# Out:
#    population numeric  householdsize numeric  racepctblack numeric  \
# 0            0.000270               0.407609              0.014172
# 1            0.001794               0.331522              0.008276
# 2            0.002645               0.225543              0.007655
# 3            0.000910               0.217391              0.017586
# 4            0.017845               0.230978              0.025965
#
#    racePctWhite numeric  racePctAsian numeric  racePctHisp numeric  \
# 0              0.919030              0.112659             0.018493
# 1              0.958123              0.059377             0.007670
# 2              0.945333              0.059203             0.023432
# 3              0.976483              0.008184             0.006094
# 4              0.958948              0.015149             0.008721
#
#    agePct12t21 numeric  agePct12t29 numeric  agePct16t24 numeric  \
# 0             0.158370             0.197284             0.106646
# 1             0.129065             0.194994             0.099017
# 2             0.136090             0.269917             0.108003
# 3             0.159976             0.258793             0.128009
# 4             0.271176             0.384590             0.261105
#
#    agePct65up numeric  numbUrban numeric  pctUrban numeric  medIncome numeric  \
# 0            0.189200           0.001636               1.0           0.567127
# 1            0.303659           0.003158               1.0           0.324331
# 2            0.168656           0.004007               1.0           0.215022
# 3            0.311289           0.000000               0.0           0.080358
# 4            0.226961           0.019186               1.0           0.089256
#
#    pctWWage numeric  ...  MedOwnCostPctInc numeric  \
# 0          0.886357  ...                  1.000000
# 1          0.728519  ...                  0.537701
# 2          0.774869  ...                  0.360939
# 3          0.561595  ...                  0.174289
# 4          0.679088  ...                  0.182942
#
#    MedOwnCostPctIncNoMtg numeric  NumInShelters numeric  NumStreet numeric  \
# 0                       0.440594               0.376344           0.293233
# 1                       0.628713               0.354839           0.180451
# 2                       0.455446               0.408602           0.112782
# 3                       0.683168               0.349462           0.330827
# 4                       0.569307               0.172043           0.120301
#
#    PctForeignBorn numeric  PctBornSameState numeric  PctSameHouse85 numeric  \
# 0                0.000470                  0.000000                0.174029
# 1                0.000000                  0.000000                0.134839
# 2                0.000684                  0.000000                0.080040
# 3                0.000000                  0.000000                0.030887
# 4                0.013985                  0.000383                0.021754
#
#    PctSameCity85 numeric  PctSameState85 numeric  LemasSwornFT numeric  \
# 0               0.543697                0.801139              0.730478
# 1               0.815141                0.890754              0.907197
# 2               0.440097                0.371197              0.485286
# 3               0.948721                0.672411              0.906469
# 4               0.666744                0.456466              0.621503
#
#    LemasSwFTPerPop numeric  PctUsePubTrans numeric  PolicCars numeric  \
# 0                 0.839571                0.001569           0.041518
# 1                 0.943641                0.002718           0.049224
# 2                 0.745788                0.002718           0.062662
# 3                 0.945430                0.001205           0.072540
# 4                 0.787685                0.019474           0.044905
#
#    PolicOperBudg numeric
# 0               0.177250
# 1               0.070679
# 2               0.080434
# 3               0.060924
# 4               0.017854
#
# [5 rows x 100 columns]
